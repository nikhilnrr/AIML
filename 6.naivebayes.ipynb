# %%
import pandas as pd 
import numpy as np
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data = pd.read_csv('social_network.csv.csv')

# %%
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
data = data.drop(['User ID'],axis =1)

# %%
y = data.iloc[:, -1].values

# %%
le = LabelEncoder()

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
x_test, x_train, y_test, y_train = train_test_split(x, y, test_size=0.2)

# %%
gb = GaussianNB()
gb.fit(x_train, y_train)
y_predgb = gb.predict(x_test)

# %%
print(accuracy_score(y_test, y_predgb))
# Out:
# 0.89375

# %%
print(confusion_matrix(y_test, y_predgb))
# Out:
# [[191  14]
#  [ 20  95]]

# %%
def n(a):
    if a==0:
        return("setosa")
    elif a == 1:
        return("virginica")
    else:
        return("vercicolor")

# %%
for(i) in range(len(x_test)):
    print(f"Actual : {x_test[i]}, Class Label {n(y_test[i])}, predicted {n(y_predgb[i])}")
# Out:
# Actual : [    1    24 55000], Class Label setosa, predicted setosa
# Actual : [     0     49 141000], Class Label virginica, predicted virginica
# Actual : [     1     34 115000], Class Label setosa, predicted setosa
# Actual : [     0     48 131000], Class Label virginica, predicted virginica
# Actual : [    0    24 55000], Class Label setosa, predicted setosa
# Actual : [    1    35 53000], Class Label setosa, predicted setosa
# Actual : [    1    26 81000], Class Label setosa, predicted setosa
# Actual : [    0    36 75000], Class Label setosa, predicted setosa
# Actual : [    1    25 80000], Class Label setosa, predicted setosa
# Actual : [    1    37 72000], Class Label setosa, predicted setosa
# Actual : [     1     47 105000], Class Label virginica, predicted virginica
# Actual : [    1    57 74000], Class Label virginica, predicted virginica
# Actual : [    1    21 72000], Class Label setosa, predicted setosa
# Actual : [    0    46 22000], Class Label setosa, predicted virginica
# Actual : [    1    49 65000], Class Label setosa, predicted virginica
# Actual : [    0    39 73000], Class Label setosa, predicted setosa
# Actual : [     1     39 134000], Class Label virginica, predicted virginica
# Actual : [    1    38 51000], Class Label setosa, predicted setosa
# Actual : [    1    45 22000], Class Label virginica, predicted virginica
# Actual : [    0    40 72000], Class Label setosa, predicted setosa
# Actual : [    0    35 50000], Class Label setosa, predicted setosa
# Actual : [    1    41 52000], Class Label setosa, predicted setosa
# Actual : [    0    52 90000], Class Label virginica, predicted virginica
# Actual : [    0    54 26000], Class Label virginica, predicted virginica
# Actual : [    0    48 96000], Class Label virginica, predicted virginica
# Actual : [    0    18 44000], Class Label setosa, predicted setosa
# Actual : [     0     33 149000], Class Label virginica, predicted virginica
# Actual : [     1     34 112000], Class Label virginica, predicted setosa
# Actual : [     0     51 134000], Class Label setosa, predicted virginica
# Actual : [    1    48 33000], Class Label virginica, predicted virginica
# Actual : [    0    58 38000], Class Label virginica, predicted virginica
# Actual : [    1    39 96000], Class Label virginica, predicted setosa
# Actual : [     1     32 120000], Class Label virginica, predicted setosa
# Actual : [    0    39 75000], Class Label virginica, predicted setosa
# Actual : [    0    48 35000], Class Label virginica, predicted virginica
# Actual : [    0    47 30000], Class Label virginica, predicted virginica
# Actual : [    1    19 70000], Class Label setosa, predicted setosa
# Actual : [    1    35 61000], Class Label setosa, predicted setosa
# Actual : [    1    30 80000], Class Label setosa, predicted setosa
# Actual : [    0    27 58000], Class Label setosa, predicted setosa
# Actual : [    0    44 39000], Class Label setosa, predicted setosa
# Actual : [    1    22 81000], Class Label setosa, predicted setosa
# Actual : [    1    40 75000], Class Label setosa, predicted setosa
# Actual : [    0    46 74000], Class Label setosa, predicted virginica
# Actual : [     0     43 112000], Class Label virginica, predicted virginica
# Actual : [    1    46 23000], Class Label virginica, predicted virginica
# Actual : [    0    45 22000], Class Label virginica, predicted virginica
# Actual : [    1    41 72000], Class Label setosa, predicted setosa
# Actual : [    0    23 28000], Class Label setosa, predicted setosa
# Actual : [    0    35 44000], Class Label setosa, predicted setosa
# Actual : [    0    35 47000], Class Label setosa, predicted setosa
# Actual : [    1    37 55000], Class Label setosa, predicted setosa
# Actual : [    0    23 82000], Class Label setosa, predicted setosa
# Actual : [    0    36 50000], Class Label setosa, predicted setosa
# Actual : [    1    60 42000], Class Label virginica, predicted virginica
# Actual : [    0    29 83000], Class Label setosa, predicted setosa
# Actual : [     1     58 144000], Class Label virginica, predicted virginica
# Actual : [    1    27 20000], Class Label setosa, predicted setosa
# Actual : [     0     43 133000], Class Label setosa, predicted virginica
# Actual : [    1    29 80000], Class Label setosa, predicted setosa
# Actual : [    1    31 76000], Class Label setosa, predicted setosa
# Actual : [    1    30 87000], Class Label setosa, predicted setosa
# Actual : [     0     54 108000], Class Label virginica, predicted virginica
# Actual : [    0    20 23000], Class Label setosa, predicted setosa
# Actual : [    1    46 59000], Class Label setosa, predicted setosa
# Actual : [    0    41 71000], Class Label setosa, predicted setosa
# Actual : [    1    37 70000], Class Label virginica, predicted setosa
# Actual : [    0    38 55000], Class Label setosa, predicted setosa
# Actual : [     0     32 135000], Class Label virginica, predicted virginica
# Actual : [    0    23 48000], Class Label setosa, predicted setosa
# Actual : [    1    23 20000], Class Label setosa, predicted setosa
# Actual : [    1    39 77000], Class Label setosa, predicted setosa
# Actual : [    0    24 32000], Class Label setosa, predicted setosa
# Actual : [    0    35 77000], Class Label setosa, predicted setosa
# Actual : [    1    41 87000], Class Label virginica, predicted setosa
# Actual : [    0    37 78000], Class Label virginica, predicted setosa
# Actual : [    1    40 47000], Class Label setosa, predicted setosa
# Actual : [     0     55 125000], Class Label virginica, predicted virginica
# Actual : [    1    39 71000], Class Label setosa, predicted setosa
# Actual : [    1    28 79000], Class Label setosa, predicted setosa
# Actual : [    0    38 80000], Class Label setosa, predicted setosa
# Actual : [    1    45 26000], Class Label virginica, predicted virginica
# Actual : [    0    20 36000], Class Label setosa, predicted setosa
# Actual : [    0    38 50000], Class Label setosa, predicted setosa
# Actual : [    0    33 69000], Class Label setosa, predicted setosa
# Actual : [     0     47 144000], Class Label virginica, predicted virginica
# Actual : [     1     56 133000], Class Label virginica, predicted virginica
# Actual : [    1    35 88000], Class Label setosa, predicted setosa
# Actual : [    0    19 21000], Class Label setosa, predicted setosa
# Actual : [    0    40 60000], Class Label setosa, predicted setosa
# Actual : [    1    35 91000], Class Label virginica, predicted setosa
# Actual : [    1    18 82000], Class Label setosa, predicted setosa
# Actual : [    1    25 87000], Class Label setosa, predicted setosa
# Actual : [    0    19 26000], Class Label setosa, predicted setosa
# Actual : [    0    35 60000], Class Label setosa, predicted setosa
# Actual : [    0    26 17000], Class Label setosa, predicted setosa
# Actual : [    0    27 57000], Class Label setosa, predicted setosa
# Actual : [    0    35 71000], Class Label setosa, predicted setosa
# Actual : [    1    25 22000], Class Label setosa, predicted setosa
# Actual : [     0     48 138000], Class Label virginica, predicted virginica
# Actual : [    0    38 65000], Class Label setosa, predicted setosa
# Actual : [    1    47 34000], Class Label virginica, predicted virginica
# Actual : [    0    53 82000], Class Label virginica, predicted virginica
# Actual : [    1    35 22000], Class Label setosa, predicted setosa
# Actual : [     1     42 104000], Class Label virginica, predicted virginica
# Actual : [    0    60 46000], Class Label virginica, predicted virginica
# Actual : [    1    47 25000], Class Label virginica, predicted virginica
# Actual : [    0    58 47000], Class Label virginica, predicted virginica
# Actual : [    1    39 42000], Class Label setosa, predicted setosa
# Actual : [     0     52 138000], Class Label virginica, predicted virginica
# Actual : [    1    37 79000], Class Label virginica, predicted setosa
# Actual : [    1    28 59000], Class Label setosa, predicted setosa
# Actual : [    1    27 58000], Class Label setosa, predicted setosa
# Actual : [     1     30 135000], Class Label virginica, predicted virginica
# Actual : [     0     38 113000], Class Label virginica, predicted virginica
# Actual : [    1    33 31000], Class Label setosa, predicted setosa
# Actual : [     0     40 142000], Class Label virginica, predicted virginica
# Actual : [    1    33 43000], Class Label setosa, predicted setosa
# Actual : [    0    28 85000], Class Label setosa, predicted setosa
# Actual : [    0    46 41000], Class Label virginica, predicted virginica
# Actual : [    0    36 63000], Class Label setosa, predicted setosa
# Actual : [    1    60 42000], Class Label virginica, predicted virginica
# Actual : [     1     60 102000], Class Label virginica, predicted virginica
# Actual : [    0    33 51000], Class Label setosa, predicted setosa
# Actual : [    0    28 44000], Class Label setosa, predicted setosa
# Actual : [     0     37 146000], Class Label virginica, predicted virginica
# Actual : [    1    38 59000], Class Label setosa, predicted setosa
# Actual : [     0     32 117000], Class Label setosa, predicted setosa
# Actual : [    1    26 16000], Class Label setosa, predicted setosa
# Actual : [    0    39 61000], Class Label setosa, predicted setosa
# Actual : [    1    35 50000], Class Label setosa, predicted setosa
# Actual : [    1    22 18000], Class Label setosa, predicted setosa
# Actual : [     1     35 108000], Class Label setosa, predicted setosa
# Actual : [    0    35 97000], Class Label virginica, predicted setosa
# Actual : [     1     39 122000], Class Label virginica, predicted virginica
# Actual : [    1    42 73000], Class Label virginica, predicted setosa
# Actual : [    0    31 34000], Class Label setosa, predicted setosa
# Actual : [    1    42 65000], Class Label setosa, predicted setosa
# Actual : [     1     43 129000], Class Label virginica, predicted virginica
# Actual : [     0     47 113000], Class Label virginica, predicted virginica
# Actual : [    1    20 86000], Class Label setosa, predicted setosa
# Actual : [    0    42 79000], Class Label setosa, predicted setosa
# Actual : [    0    53 34000], Class Label virginica, predicted virginica
# Actual : [     0     53 143000], Class Label virginica, predicted virginica
# Actual : [     0     52 114000], Class Label setosa, predicted virginica
# Actual : [    0    59 42000], Class Label setosa, predicted virginica
# Actual : [    1    40 57000], Class Label setosa, predicted setosa
# Actual : [    0    30 79000], Class Label setosa, predicted setosa
# Actual : [    0    37 93000], Class Label virginica, predicted setosa
# Actual : [    1    36 33000], Class Label setosa, predicted setosa
# Actual : [    1    20 74000], Class Label setosa, predicted setosa
# Actual : [    1    24 84000], Class Label setosa, predicted setosa
# Actual : [    0    31 89000], Class Label setosa, predicted setosa
# Actual : [    0    35 25000], Class Label setosa, predicted setosa
# Actual : [    0    27 96000], Class Label virginica, predicted setosa
# Actual : [     1     36 118000], Class Label virginica, predicted virginica
# Actual : [    0    21 16000], Class Label setosa, predicted setosa
# Actual : [     1     40 107000], Class Label virginica, predicted virginica
# Actual : [    1    21 88000], Class Label setosa, predicted setosa
# Actual : [    0    39 71000], Class Label setosa, predicted setosa
# Actual : [    1    24 19000], Class Label setosa, predicted setosa
# Actual : [    1    30 17000], Class Label setosa, predicted setosa
# Actual : [    1    36 60000], Class Label setosa, predicted setosa
# Actual : [     1     52 150000], Class Label virginica, predicted virginica
# Actual : [    0    37 62000], Class Label setosa, predicted setosa
# Actual : [    0    36 54000], Class Label setosa, predicted setosa
# Actual : [     0     37 137000], Class Label virginica, predicted virginica
# Actual : [    1    19 85000], Class Label setosa, predicted setosa
# Actual : [    0    39 79000], Class Label setosa, predicted setosa
# Actual : [    0    37 33000], Class Label setosa, predicted setosa
# Actual : [    1    35 59000], Class Label setosa, predicted setosa
# Actual : [    0    50 44000], Class Label setosa, predicted virginica
# Actual : [    1    24 58000], Class Label setosa, predicted setosa
# Actual : [     0     35 147000], Class Label virginica, predicted virginica
# Actual : [    1    31 66000], Class Label setosa, predicted setosa
# Actual : [    0    26 52000], Class Label setosa, predicted setosa
# Actual : [     0     48 119000], Class Label virginica, predicted virginica
# Actual : [    0    42 75000], Class Label setosa, predicted setosa
# Actual : [    0    33 28000], Class Label setosa, predicted setosa
# Actual : [     0     48 134000], Class Label virginica, predicted virginica
# Actual : [    1    37 75000], Class Label setosa, predicted setosa
# Actual : [    0    49 39000], Class Label virginica, predicted virginica
# Actual : [    1    41 52000], Class Label setosa, predicted setosa
# Actual : [    0    26 72000], Class Label setosa, predicted setosa
# Actual : [    1    26 86000], Class Label setosa, predicted setosa
# Actual : [    0    59 83000], Class Label setosa, predicted virginica
# Actual : [    0    49 36000], Class Label virginica, predicted virginica
# Actual : [    0    28 37000], Class Label setosa, predicted setosa
# Actual : [    0    31 68000], Class Label setosa, predicted setosa
# Actual : [    0    30 62000], Class Label setosa, predicted setosa
# Actual : [    1    18 52000], Class Label setosa, predicted setosa
# Actual : [    1    26 32000], Class Label setosa, predicted setosa
# Actual : [     1     30 107000], Class Label virginica, predicted setosa
# Actual : [    1    48 74000], Class Label virginica, predicted virginica
# Actual : [    1    60 83000], Class Label virginica, predicted virginica
# Actual : [     1     39 106000], Class Label virginica, predicted virginica
# Actual : [    0    18 86000], Class Label setosa, predicted setosa
# Actual : [     0     53 104000], Class Label virginica, predicted virginica
# Actual : [    0    50 20000], Class Label virginica, predicted virginica
# Actual : [    1    57 60000], Class Label virginica, predicted virginica
# Actual : [    1    37 77000], Class Label setosa, predicted setosa
# Actual : [    0    42 70000], Class Label setosa, predicted setosa
# Actual : [    1    25 90000], Class Label setosa, predicted setosa
# Actual : [    1    40 57000], Class Label setosa, predicted setosa
# Actual : [    1    37 74000], Class Label setosa, predicted setosa
# Actual : [    1    46 79000], Class Label virginica, predicted virginica
# Actual : [    0    41 30000], Class Label setosa, predicted setosa
# Actual : [    1    40 61000], Class Label setosa, predicted setosa
# Actual : [     0     57 122000], Class Label virginica, predicted virginica
# Actual : [     1     36 125000], Class Label virginica, predicted virginica
# Actual : [    0    22 27000], Class Label setosa, predicted setosa
# Actual : [    1    51 23000], Class Label virginica, predicted virginica
# Actual : [    0    26 35000], Class Label setosa, predicted setosa
# Actual : [    1    40 71000], Class Label virginica, predicted setosa
# Actual : [    1    35 79000], Class Label setosa, predicted setosa
# Actual : [    1    29 75000], Class Label setosa, predicted setosa
# Actual : [    0    34 25000], Class Label setosa, predicted setosa
# Actual : [    1    30 89000], Class Label setosa, predicted setosa
# Actual : [    0    26 80000], Class Label setosa, predicted setosa
# Actual : [    0    24 27000], Class Label setosa, predicted setosa
# Actual : [    0    34 43000], Class Label setosa, predicted setosa
# Actual : [    1    26 80000], Class Label setosa, predicted setosa
# Actual : [     1     42 149000], Class Label virginica, predicted virginica
# Actual : [    1    48 33000], Class Label virginica, predicted virginica
# Actual : [    1    25 33000], Class Label setosa, predicted setosa
# Actual : [     0     55 130000], Class Label virginica, predicted virginica
# Actual : [    0    29 47000], Class Label setosa, predicted setosa
# Actual : [    0    41 72000], Class Label setosa, predicted setosa
# Actual : [    0    31 15000], Class Label setosa, predicted setosa
# Actual : [    0    50 36000], Class Label virginica, predicted virginica
# Actual : [    1    36 99000], Class Label virginica, predicted setosa
# Actual : [    0    52 21000], Class Label virginica, predicted virginica
# Actual : [    1    35 55000], Class Label setosa, predicted setosa
# Actual : [    1    46 88000], Class Label virginica, predicted virginica
# Actual : [    0    23 66000], Class Label setosa, predicted setosa
# Actual : [    1    39 42000], Class Label setosa, predicted setosa
# Actual : [    0    46 96000], Class Label setosa, predicted virginica
# Actual : [    1    54 70000], Class Label virginica, predicted virginica
# Actual : [    1    35 72000], Class Label setosa, predicted setosa
# Actual : [    0    41 72000], Class Label setosa, predicted setosa
# Actual : [    1    19 19000], Class Label setosa, predicted setosa
# Actual : [     0     58 101000], Class Label virginica, predicted virginica
# Actual : [    1    32 18000], Class Label setosa, predicted setosa
# Actual : [    1    26 30000], Class Label setosa, predicted setosa
# Actual : [    0    35 23000], Class Label setosa, predicted setosa
# Actual : [    1    35 38000], Class Label setosa, predicted setosa
# Actual : [    0    35 57000], Class Label setosa, predicted setosa
# Actual : [    0    57 33000], Class Label virginica, predicted virginica
# Actual : [    0    29 83000], Class Label setosa, predicted setosa
# Actual : [    0    39 59000], Class Label setosa, predicted setosa
# Actual : [    1    19 76000], Class Label setosa, predicted setosa
# Actual : [    0    46 32000], Class Label virginica, predicted virginica
# Actual : [    0    41 51000], Class Label setosa, predicted setosa
# Actual : [    1    56 60000], Class Label virginica, predicted virginica
# Actual : [     0     54 104000], Class Label virginica, predicted virginica
# Actual : [    1    40 65000], Class Label setosa, predicted setosa
# Actual : [    1    49 88000], Class Label virginica, predicted virginica
# Actual : [    1    35 27000], Class Label setosa, predicted setosa
# Actual : [     0     42 108000], Class Label virginica, predicted virginica
# Actual : [    1    60 34000], Class Label virginica, predicted virginica
# Actual : [    1    31 18000], Class Label setosa, predicted setosa
# Actual : [     0     39 134000], Class Label virginica, predicted virginica
# Actual : [    0    18 68000], Class Label setosa, predicted setosa
# Actual : [    1    49 28000], Class Label virginica, predicted virginica
# Actual : [    0    33 41000], Class Label setosa, predicted setosa
# Actual : [    1    42 65000], Class Label setosa, predicted setosa
# Actual : [     0     45 131000], Class Label virginica, predicted virginica
# Actual : [    1    27 90000], Class Label setosa, predicted setosa
# Actual : [     0     47 107000], Class Label virginica, predicted virginica
# Actual : [    1    49 86000], Class Label virginica, predicted virginica
# Actual : [    0    27 17000], Class Label setosa, predicted setosa
# Actual : [     0     32 150000], Class Label virginica, predicted virginica
# Actual : [    1    38 61000], Class Label setosa, predicted setosa
# Actual : [    1    49 28000], Class Label virginica, predicted virginica
# Actual : [    1    29 43000], Class Label setosa, predicted setosa
# Actual : [    1    45 32000], Class Label virginica, predicted setosa
# Actual : [    0    27 84000], Class Label setosa, predicted setosa
# Actual : [    0    47 49000], Class Label virginica, predicted virginica
# Actual : [    1    48 41000], Class Label virginica, predicted virginica
# Actual : [    1    27 89000], Class Label setosa, predicted setosa
# Actual : [    0    37 80000], Class Label setosa, predicted setosa
# Actual : [    1    41 45000], Class Label setosa, predicted setosa
# Actual : [    0    32 86000], Class Label setosa, predicted setosa
# Actual : [    0    58 95000], Class Label virginica, predicted virginica
# Actual : [    0    46 82000], Class Label setosa, predicted virginica
# Actual : [    1    38 71000], Class Label setosa, predicted setosa
# Actual : [    1    35 58000], Class Label setosa, predicted setosa
# Actual : [    1    34 43000], Class Label setosa, predicted setosa
# Actual : [    1    47 20000], Class Label virginica, predicted virginica
# Actual : [    1    35 73000], Class Label setosa, predicted setosa
# Actual : [     1     59 130000], Class Label virginica, predicted virginica
# Actual : [    0    47 50000], Class Label virginica, predicted virginica
# Actual : [    1    37 52000], Class Label setosa, predicted setosa
# Actual : [    1    26 15000], Class Label setosa, predicted setosa
# Actual : [    1    28 32000], Class Label setosa, predicted setosa
# Actual : [    0    26 15000], Class Label setosa, predicted setosa
# Actual : [    1    38 61000], Class Label setosa, predicted setosa
# Actual : [    0    35 72000], Class Label setosa, predicted setosa
# Actual : [    1    37 53000], Class Label setosa, predicted setosa
# Actual : [     0     33 113000], Class Label setosa, predicted setosa
# Actual : [    0    45 45000], Class Label virginica, predicted setosa
# Actual : [    0    37 71000], Class Label setosa, predicted setosa
# Actual : [     0     31 118000], Class Label virginica, predicted setosa
# Actual : [    1    25 79000], Class Label setosa, predicted setosa
# Actual : [    1    35 39000], Class Label setosa, predicted setosa
# Actual : [    1    41 79000], Class Label setosa, predicted setosa
# Actual : [    1    27 88000], Class Label setosa, predicted setosa
# Actual : [    0    50 88000], Class Label virginica, predicted virginica
# Actual : [    0    41 63000], Class Label setosa, predicted setosa
# Actual : [    0    42 90000], Class Label virginica, predicted setosa
# Actual : [    1    47 43000], Class Label setosa, predicted virginica
# Actual : [    1    45 79000], Class Label setosa, predicted virginica
# Actual : [     0     38 112000], Class Label setosa, predicted virginica
# Actual : [     0     27 137000], Class Label virginica, predicted virginica
# Actual : [    1    40 59000], Class Label setosa, predicted setosa
# Actual : [    1    40 57000], Class Label setosa, predicted setosa
# Actual : [    1    35 75000], Class Label setosa, predicted setosa
# Actual : [    1    31 74000], Class Label setosa, predicted setosa
# Actual : [    0    41 72000], Class Label setosa, predicted setosa
# Actual : [     0     56 104000], Class Label virginica, predicted virginica
