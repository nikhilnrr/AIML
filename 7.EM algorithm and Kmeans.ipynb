# %%
import numpy as np
import pandas as pd 
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("8-Kmeans_EM.csv.csv")

# %%
f1 = data['V1']

# %%
f2 = data['V2']

# %%
x = np.array(list(zip(f1,f2)))

# %%
plt.scatter(x[:,0], x[:, 1], color = 'black')

# %%
km = KMeans(n_clusters=3)
km.fit(x)
label = km.predict(x)
centr = km.cluster_centers_
plt.scatter(x[:,0],x[:,1], c=label)
plt.scatter(centr[:,0],centr[:,1], marker="*")
# Out:
# C:\Users\nikhi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
km = KMeans(n_clusters=4)
km.fit(x)
labels = km.predict(x)
centr = km.cluster_centers_

print(labels)

plt.scatter(x[:, 0], x[:,1], c=labels)
plt.scatter(centr[:,0], centr[:,1], marker="*")
# Out:
# [1 1 1 ... 0 0 0]
# C:\Users\nikhi\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
km = GaussianMixture(n_components=3)
km.fit(x)
label = km.predict(x)
plt.scatter(x[:, 0], x[:, 1], c=label)
